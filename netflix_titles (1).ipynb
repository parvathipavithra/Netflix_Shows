# %% [raw]
# Reading Data

# %%
import pandas as pd
x=pd.read_csv("D:\\dataset\\netflix_titles.csv")
x
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
x.shape
# Out:
# (8807, 12)

# %%
x.size
# Out:
# 105684

# %%
x.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
x.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
x.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
x.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
x.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
x=x.drop(columns=['title','director','cast','listed_in'],axis=1)
x
# Out:
#      show_id     type        country          date_added  release_year rating  \
# 0         s1    Movie  United States  September 25, 2021          2020  PG-13
# 1         s2  TV Show   South Africa  September 24, 2021          2021  TV-MA
# 2         s3  TV Show            NaN  September 24, 2021          2021  TV-MA
# 3         s4  TV Show            NaN  September 24, 2021          2021  TV-MA
# 4         s5  TV Show          India  September 24, 2021          2021  TV-MA
# ...      ...      ...            ...                 ...           ...    ...
# 8802   s8803    Movie  United States   November 20, 2019          2007      R
# 8803   s8804  TV Show            NaN        July 1, 2019          2018  TV-Y7
# 8804   s8805    Movie  United States    November 1, 2019          2009      R
# 8805   s8806    Movie  United States    January 11, 2020          2006     PG
# 8806   s8807    Movie          India       March 2, 2019          2015  TV-14
#
# ...

# %% [raw]
# Count of Movies and Tv show

# %%
x.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %% [raw]
# Plot the count of Movies and Tv shows

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")
sns.countplot(data=x,x='type',hue=x['type'])
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Count of Movies and TV show')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# Year_count()

# %%
x.groupby('release_year').release_year.count()
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: release_year, Length: 74, dtype: int64

# %%
import pandas as pd
x=pd.read_csv("D:\\dataset\\netflix_titles.csv")
x
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [raw]
# Heatmap

# %%
import seaborn as sns
sns.heatmap(x.isnull())
# Out:
# <Axes: >

# %% [raw]
# isin()--Show information for 'House of Cards' in title

# %%
x[x['title'].isin(['House of Cards'])]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [raw]
# Movies Released in India

# %%
x[(x['type']=='Movie')&(x['country']=='India')]['title']
# Out:
# 24                      Jeans
# 105          Angamaly Diaries
# 114                    Anjaam
# 116                    Dhanak
# 118                   Gurgaon
#                 ...
# 8772    Yamla Pagla Deewana 2
# 8773      Yanda Kartavya Aahe
# 8798                 Zed Plus
# 8799                    Zenda
# 8806                   Zubaan
# Name: title, Length: 893, dtype: object

# %% [raw]
# Show directors using value_counts()

# %%
x['director'].nunique()
# Out:
# 4528

# %%
x['director'].value_counts().head(20)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Don Michael Paul          10
# David Dhawan               9
# Yılmaz Erdoğan             8
# Lance Bangs                8
# Kunle Afolayan             8
# Quentin Tarantino          8
# Ryan Polito                8
# Troy Miller                8
# Shannon Hartman            8
# Fernando Ayllón            8
# Name: count, dtype: int64

# %% [raw]
# Show Countries using value_counts()

# %%
import pandas as pd
x=pd.read_csv("D:\\dataset\\netflix_titles.csv")
x['country'].nunique()
# Out:
# 748

# %%
x['country'].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %% [raw]
# Show date_added using value_counts()

# %%
x['date_added'].nunique()
# Out:
# 1767

# %%
x['date_added'].value_counts().head(15)
# Out:
# date_added
# January 1, 2020      109
# November 1, 2019      89
# March 1, 2018         75
# December 31, 2019     74
# October 1, 2018       71
# October 1, 2019       60
# July 1, 2021          60
# November 1, 2018      60
# September 1, 2021     56
# July 1, 2019          52
# January 1, 2018       52
# June 2, 2021          51
# January 1, 2021       49
# October 1, 2017       47
# April 1, 2018         44
# Name: count, dtype: int64

# %% [raw]
# Show release_year using value_counts()

# %%
x['release_year'].value_counts().head(15)
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# 2010     194
# 2011     185
# 2009     152
# 2008     136
# 2006      96
# Name: count, dtype: int64

# %% [raw]
# Show ratings using value_counts()

# %%
x['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
x['rating'].value_counts(normalize=True)
# Out:
# rating
# TV-MA       0.364308
# TV-14       0.245371
# TV-PG       0.098035
# R           0.090765
# PG-13       0.055663
# TV-Y7       0.037942
# TV-Y        0.034874
# PG          0.032603
# TV-G        0.024991
# NR          0.009088
# G           0.004658
# TV-Y7-FV    0.000682
# NC-17       0.000341
# UR          0.000341
# 74 min      0.000114
# 84 min      0.000114
# 66 min      0.000114
# Name: proportion, dtype: float64

# %% [raw]
# Plot the ratings

# %%
sns.countplot(y=x['rating'],hue=x['rating'])
# Out:
# <Axes: xlabel='count', ylabel='rating'>

# %% [raw]
# Show the information of duration in unique values

# %%
x.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %% [raw]
# Show the information of Movies based on Countries

# %%
x_Movie=x[x['type']=='Movie']

# %%
x_Movie.country.value_counts()
# Out:
# country
# United States                            2058
# India                                     893
# United Kingdom                            206
# Canada                                    122
# Spain                                      97
#                                          ...
# United Kingdom, Russia, United States       1
# Paraguay, Argentina                         1
# United Kingdom, Malawi                      1
# Austria, Iraq, United States                1
# United Arab Emirates, Jordan                1
# Name: count, Length: 651, dtype: int64

# %%
import pandas as pd
x=pd.read_csv("D:\\dataset\\netflix_titles.csv")
x
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [raw]
# Show the information of Movies released in 2015 using AND operator

# %%
x[(x['type']=='Movie')&(x['release_year']==2015)]
# Out:
#      show_id   type                  title           director  \
# 116     s117  Movie                 Dhanak    Nagesh Kukunoor
# 133     s134  Movie                Chappie     Neill Blomkamp
# 141     s142  Movie             Extraction   Steven C. Miller
# 173     s174  Movie  Snervous Tyler Oakley           Amy Rice
# 257     s258  Movie       O Kadhal Kanmani        Mani Ratnam
# ...      ...    ...                    ...                ...
# 8779   s8780  Movie          Yes or No 2.5  Kirati Nakintanon
# 8784   s8785  Movie   Yoko and His Friends                NaN
# 8788   s8789  Movie           You Carry Me         Ivona Juka
# 8801   s8802  Movie                Zinzana    Majid Al Ansari
# 8806   s8807  Movie                 Zubaan        Mozez Singh
#
#                                                    cast  \
# 116   Krrish Chhabria, Hetal Gada, Vipin Sharma, Gul...
# 133   Sharlto Copley, Hugh Jackman, Sigourney Weaver...
# ...

# %% [raw]
# Show the information of Tv Show released in 2018 using AND operator

# %%
x[(x['type']=='TV Show')&(x['release_year']==2018)]
# Out:
#      show_id     type                                       title director  \
# 21       s22  TV Show                      Resurrection: Ertugrul      NaN
# 37       s38  TV Show                                 Angry Birds      NaN
# 265     s266  TV Show  Rascal Does Not Dream of Bunny Girl Senpai      NaN
# 288     s289  TV Show                     Las muñecas de la mafia      NaN
# 513     s514  TV Show                                      Colony      NaN
# ...      ...      ...                                         ...      ...
# 8604   s8605  TV Show                Top 10 Secrets and Mysteries      NaN
# 8605   s8606  TV Show                                   Top Grier      NaN
# 8646   s8647  TV Show                                  Twirlywoos      NaN
# 8775   s8776  TV Show                             Yeh Meri Family      NaN
# 8803   s8804  TV Show                                 Zombie Dumb      NaN
#
#                                                    cast  \
# ...

# %% [raw]
# Tv Shows in India using AND operator

# %%
x[(x['type']=='TV Show') & (x['country']=='India')]['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %% [raw]
# Using AND, OR operators

# %%
x[(x['type']=='Movie')&(x['title']=='International TV Shows')|(x['type']=='TV Show')&(x['country']=='United Kingdom')]
# Out:
#      show_id     type                                   title  \
# 8         s9  TV Show           The Great British Baking Show
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# 98       s99  TV Show               Octonauts: Above & Beyond
# ...      ...      ...                                     ...
# 8646   s8647  TV Show                              Twirlywoos
# 8712   s8713  TV Show              Weird Wonders of the World
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8758   s8759  TV Show                  World's Busiest Cities
#
#              director                                               cast  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %% [raw]
# Display 'TV-14' rated movies in canada using AND operator

# %%
x[(x['type']=='Movie')&(x['rating']=='TV-14')&(x['country']=='Canada')].shape
# Out:
# (13, 12)

# %%
x[(x['type']=='Movie')&(x['rating']=='TV-14')&(x['country']=='Canada')]
# Out:
#      show_id   type                                        title  \
# 157     s158  Movie                                     Level 16
# 1279   s1280  Movie   Made You Look: A True Story About Fake Art
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5972   s5973  Movie                             #cats_the_mewvie
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8178   s8179  Movie                  The Accountant of Auschwitz
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director  \
# ...

# %% [raw]
# 'R' rated TV Shows after 2015

# %%
x[(x['type']=='TV Show')&(x['rating']=='R')&(x['release_year']>2015)]
# Out:
#      show_id     type  title director  \
# 7593   s7594  TV Show  Nobel      NaN
#
#                                                    cast country  \
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
#
#              date_added  release_year rating  duration  \
# 7593  December 10, 2016          2016      R  1 Season
#
#                                             listed_in  \
# 7593  International TV Shows, TV Dramas, TV Thrillers
#
#                                             description
# 7593  A series of incidents in Afghanistan set compl...

# %% [raw]
# Display 90minutes movies it was released in 2020

# %%
x[(x['type']=='Movie')&(x['duration']=='90 min')&(x['release_year']==2020)]
# Out:
#      show_id   type                                       title  \
# 0         s1  Movie                        Dick Johnson Is Dead
# 229     s230  Movie                                The Old Ways
# 1177   s1178  Movie                                    Hospital
# 1279   s1280  Movie  Made You Look: A True Story About Fake Art
# 1577   s1578  Movie   Emicida: AmarElo - It’s All For Yesterday
# 1731   s1732  Movie                A New York Christmas Wedding
# 1987   s1988  Movie                                     Residue
# 2149   s2150  Movie                      We Summon the Darkness
# 2232   s2233  Movie                                Fatal Affair
# 2360   s2361  Movie                         One-Way to Tomorrow
# 2416   s2417  Movie                             The Night Clerk
# 2540   s2541  Movie                             The Wrong Missy
# 2572   s2573  Movie                                       Roped
# 3046   s3047  Movie               All the Freckles in the World
# ...

# %% [raw]
# Sorting the data by release year

# %%
x.sort_values(by='release_year').head(10)
# Out:
#      show_id     type                                             title  \
# 4250   s4251  TV Show                 Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                    Prelude to War
# 8205   s8206    Movie                              The Battle of Midway
# 8660   s8661    Movie     Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie                Why We Fight: The Battle of Russia
# 8763   s8764    Movie                   WWII: Report from the Aleutians
# 8640   s8641    Movie                                  Tunisian Victory
# 8436   s8437    Movie                                 The Negro Soldier
# 8419   s8420    Movie  The Memphis Belle: A Story of a\nFlying Fortress
# 7930   s7931    Movie                                        San Pietro
#
#                                                director  \
# 4250                                                NaN
# 7790                                        Frank Capra
# ...

# %% [raw]
# Sorting the data by ratings

# %%
x.sort_values(by='rating').head(10)
# Out:
#      show_id   type                                 title  \
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store
# 5541   s5542  Movie                       Louis C.K. 2017
# 5794   s5795  Movie                 Louis C.K.: Hilarious
# 8466   s8467  Movie             The Princess and the Frog
# 6151   s6152  Movie                      An American Tail
# 1126   s1127  Movie                          My Fair Lady
# 8455   s8456  Movie                      The Pirate Fairy
# 2911   s2912  Movie  A Shaun the Sheep Movie: Farmageddon
# 3062   s3063  Movie             Jimmy Neutron: Boy Genius
# 1557   s1558  Movie                                Canvas
#
#                          director  \
# 5813                   Louis C.K.
# 5541                   Louis C.K.
# 5794                   Louis C.K.
# 8466    Ron Clements, John Musker
# 6151                    Don Bluth
# 1126                 George Cukor
# 8455                 Peggy Holmes
# 2911  Richard Phelan, Will Becher
# ...

# %% [raw]
# Descending the data by release year

# %%
x.sort_values(by='release_year',ascending=False).head(10)
# Out:
#     show_id     type                                  title          director  \
# 693    s694    Movie                 Ali & Ratu Ratu Queens    Lucky Kuswandi
# 781    s782    Movie  Black Holes | The Edge of All We Know     Peter Galison
# 762    s763    Movie                           Sweet & Sour     Lee Kae-byeok
# 763    s764  TV Show                            Sweet Tooth               NaN
# 764    s765    Movie           Trippin' with the Kandasamys     Jayan Moodley
# 765    s766    Movie                                 Xtreme   Daniel Benmayor
# 766    s767    Movie                Alan Saldaña: Locked Up         Alex Díaz
# 767    s768  TV Show                   Creator's File: GOLD               NaN
# 768    s769    Movie                         Dancing Queens  Helena Bergström
# 770    s771    Movie              Myriam Fares: The Journey      Myriam Fares
#
#                                                   cast               country  \
# ...

# %% [raw]
# Sorting the data by ratings

# %%
x.sort_values(by='rating',ascending=False).head(10)
# Out:
#      show_id     type                                              title  \
# 8790   s8791    Movie                      You Don't Mess with the Zohan
# 7058   s7059    Movie                                      Immoral Tales
# 7988   s7989    Movie                                           Sex Doll
# 7513   s7514    Movie                          Motu Patlu: King of Kings
# 6581   s6582    Movie                                       Dear Dracula
# 7290   s7291    Movie  LEGO Ninjago: Masters of Spinjitzu: Day of the...
# 7292   s7293    Movie                                       Leo the Lion
# 7317   s7318    Movie                Little Singham aur Kaal ka Mahajaal
# 7646   s7647  TV Show                      Oh No! It's an Alien Invasion
# 1702   s1703    Movie               Fukrey Boyzzz: Space Mein Fukrapanti
#
#                 director                                               cast  \
# 8790        Dennis Dugan  Adam Sandler, John Turturro, Emmanuelle Chriqu...
# ...

# %% [raw]
# Naruto in TV shows using AND operator

# %%
x[(x['type']=='TV Show')&(x['title']=='Naruto')]
# Out:
#      show_id     type   title     director  \
# 3541   s3542  TV Show  Naruto  Hayato Date
#
#                                                    cast country  \
# 3541  Junko Takeuchi, Chie Nakamura, Noriaki Sugiyam...   Japan
#
#              date_added  release_year rating   duration  \
# 3541  September 1, 2019          2006  TV-14  9 Seasons
#
#                                  listed_in  \
# 3541  Anime Series, International TV Shows
#
#                                             description
# 3541  Guided by the spirit demon within him, orphane...

# %% [raw]
# Using OR , AND operator

# %%
x[(x['type']=='Movie')&(x['title']=='Tughlaq Durbar')|(x['type']=='TV Show')&(x['title']=="Kids' TV")]
# Out:
#    show_id   type           title                  director  \
# 78     s79  Movie  Tughlaq Durbar  Delhiprasad Deenadayalan
#
#                                           cast country          date_added  \
# 78  Vijay Sethupathi, Parthiban, Raashi Khanna     NaN  September 11, 2021
#
#     release_year rating duration                               listed_in  \
# 78          2020  TV-14  145 min  Comedies, Dramas, International Movies
#
#                                           description
# 78  A budding politician has devious plans to rise...

# %% [raw]
# Display Top countries and plot the countries

# %%
top_countries=x['country'].head(10)
top_countries
# Out:
# 0                                        United States
# 1                                         South Africa
# 2                                                  NaN
# 3                                                  NaN
# 4                                                India
# 5                                                  NaN
# 6                                                  NaN
# 7    United States, Ghana, Burkina Faso, United Kin...
# 8                                       United Kingdom
# 9                                        United States
# Name: country, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
sns.countplot(data=x,x=x['country'].head(7))
plt.xlabel('country')
plt.ylabel('count')
plt.title('Count of Top Countries')
plt.xticks(rotation=45)
plt.show()
top_countries=x['country'].head(7)
top_countries
# Out:
# 0    United States
# 1     South Africa
# 2              NaN
# 3              NaN
# 4            India
# 5              NaN
# 6              NaN
# Name: country, dtype: object

# %% [raw]
# Plotting using release year

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
sns.countplot(data=x,x=x['release_year'].head(50),hue=x['release_year'])
plt.xlabel('release_year')
plt.ylabel('count')
plt.title('Plotting using release year')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# Plot the Ratings

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
sns.countplot(data=x,x=x['rating'].head(1000),hue=x['rating'])
plt.xlabel('Rating')
plt.ylabel('count')
plt.title('Count of Ratings')
plt.xticks(rotation=45)
plt.show()
top_ratings=x['rating'].head(1000)
top_ratings
# Out:
# 0      PG-13
# 1      TV-MA
# 2      TV-MA
# 3      TV-MA
# 4      TV-MA
#        ...
# 995    TV-MA
# 996    TV-MA
# 997    TV-PG
# 998    TV-14
# 999    TV-MA
# Name: rating, Length: 1000, dtype: object

# %%
import pandas as pd
x=pd.read_csv("D:\\dataset\\netflix_titles.csv")
x
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [raw]
# Plot the TV shows using seasons

# %%
import matplotlib.pyplot as plt
plt.hist(x[x['type'] == 'TV Show']['duration'], bins=15, color='red', edgecolor='black')
plt.xlabel('Number of Seasons')
plt.ylabel('Frequency')
plt.title('Distribution of TV Show Seasons on Netflix')
plt.xticks(rotation=45, ha='right')  
plt.show()

# %% [raw]
# Plot Top 10 countries

# %%
top_countries = x['country'].value_counts().head(10)
plt.figure(figsize=(10, 6))
top_countries.plot(kind='bar', color='purple')
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Top 10 Countries Producing Netflix Content')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [raw]
# Display the release of Movies and Tv shows over the years

# %%
release_year_counts = x.groupby(['release_year', 'type']).size().unstack(fill_value=0)
release_year_counts.plot(kind='line', marker='o', figsize=(10, 6))
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.title('Trend in Release of Movies and TV Shows over the Years')
plt.legend(title='Type')
plt.show()

# %% [raw]
# Plot top common genres on netflix

# %%
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.countplot(x='listed_in', data=x, order=x['listed_in'].value_counts().index[:10])
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Top 10 Most Common Genres on Netflix')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [raw]
# Rating groupby movies and tv shows

# %%
x['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
ratings=x.groupby(['rating','type',])['type'].value_counts()
ratings
# Out:
# rating    type
# 66 min    Movie         1
# 74 min    Movie         1
# 84 min    Movie         1
# G         Movie        41
# NC-17     Movie         3
# NR        Movie        75
#           TV Show       5
# PG        Movie       287
# PG-13     Movie       490
# R         Movie       797
#           TV Show       2
# TV-14     Movie      1427
#           TV Show     733
# TV-G      Movie       126
#           TV Show      94
# TV-MA     Movie      2062
#           TV Show    1145
# TV-PG     Movie       540
#           TV Show     323
# TV-Y      Movie       131
#           TV Show     176
# TV-Y7     Movie       139
#           TV Show     195
# TV-Y7-FV  Movie         5
#           TV Show       1
# UR        Movie         3
# Name: count, dtype: int64

# %% [raw]
# Data Visualization for top 10 Movies and TV shows

# %%
directors_Movies=x['director'][x['type']=='Movie'].value_counts().sort_values(ascending=False).head(10)
print(directors_Movies)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
directors_Movies.plot(kind='barh', color='orange')
plt.title('Top 10 Movie Directors')
plt.ylabel('Directors')
plt.xlabel('Count')
plt.ylim(bottom=0)
plt.show()

# %%
directors_TV_Shows=x['director'][x['type']=='TV Show'].value_counts().sort_values(ascending=False).head(10)
print(directors_TV_Shows)
# Out:
# director
# Alastair Fothergill                    3
# Hsu Fu-chun                            2
# Iginio Straffi                         2
# Shin Won-ho                            2
# Ken Burns                              2
# Stan Lathan                            2
# Rob Seidenglanz                        2
# Luis Alfaro, Javier Gómez Santander    1
# Mauricio Dias, Tatiana Villela         1
# Brad Anderson                          1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
directors_TV_Shows.plot(kind='barh', color='salmon')
plt.title('Top 10 TV Show Directors')
plt.ylabel('Directors')
plt.xlabel('Count')
plt.ylim(bottom=0)
plt.show()

# %%
Country_Movies=x['country'][x['type']=='Movie'].value_counts().sort_values(ascending=False).head(10)
print(Country_Movies)
# Out:
# country
# United States     2058
# India              893
# United Kingdom     206
# Canada             122
# Spain               97
# Egypt               92
# Nigeria             86
# Indonesia           77
# Turkey              76
# Japan               76
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
Country_Movies.plot(kind='barh', color='magenta')
plt.title('Countrywise Top 10 Movies')
plt.ylabel('Country')
plt.xlabel('Count')
plt.ylim(bottom=0)
plt.show()

# %%
Country_TV_Shows=x['country'][x['type']=='TV Show'].value_counts().sort_values(ascending=False).head(10)
print(Country_TV_Shows)
# Out:
# country
# United States     760
# United Kingdom    213
# Japan             169
# South Korea       158
# India              79
# Taiwan             68
# Canada             59
# France             49
# Spain              48
# Australia          48
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
Country_TV_Shows.plot(kind='barh', color='cyan')
plt.title('Countrywise Top 10 TV Shows')
plt.ylabel('Country')
plt.xlabel('Count')
plt.ylim(bottom=0)
plt.show()

# %%
Datewise_Movies=x['date_added'][x['type']=='Movie'].value_counts().sort_values(ascending=False).head(10)
print(Datewise_Movies)
# Out:
# date_added
# January 1, 2020      97
# November 1, 2019     75
# March 1, 2018        72
# December 31, 2019    67
# October 1, 2018      64
# November 1, 2018     55
# July 1, 2021         53
# October 1, 2019      51
# September 1, 2021    48
# January 1, 2018      47
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
Datewise_Movies.plot(kind='bar', color='skyblue')
plt.title('Datewise top 10 movies')
plt.xlabel('Date')
plt.ylabel('Count')
plt.ylim(bottom=0)
plt.show()

# %%
Datewise_TV_Shows=x['date_added'][x['type']=='TV Show'].value_counts().sort_values(ascending=False).head(10)
print(Datewise_TV_Shows)
# Out:
# date_added
# July 6, 2021         31
# January 1, 2016      23
# August 1, 2017       22
# June 19, 2021        21
# July 1, 2017         19
# February 1, 2019     17
# December 15, 2016    14
# November 1, 2019     14
# November 15, 2019    13
# October 1, 2017      13
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
Datewise_TV_Shows.plot(kind='bar', color='maroon')
plt.title('Datewise top 10 TV shows')
plt.xlabel('Date')
plt.ylabel('Count')
plt.ylim(bottom=0)
plt.show()

# %%
Releaseyearwise_Movies=x['release_year'][x['type']=='Movie'].value_counts().sort_values(ascending=False).head(10)
print(Releaseyearwise_Movies)
# Out:
# release_year
# 2017    767
# 2018    767
# 2016    658
# 2019    633
# 2020    517
# 2015    398
# 2021    277
# 2014    264
# 2013    225
# 2012    173
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
Releaseyearwise_Movies.plot(kind='bar', color='green')
plt.title('Releaseyearwise top 10 Movies')
plt.xlabel('Year')
plt.ylabel('Count')
plt.ylim(bottom=0)
plt.show()

# %%
Releaseyearwise_TV_Shows=x['release_year'][x['type']=='TV Show'].value_counts().sort_values(ascending=False).head(10)
print(Releaseyearwise_TV_Shows)
# Out:
# release_year
# 2020    436
# 2019    397
# 2018    380
# 2021    315
# 2017    265
# 2016    244
# 2015    162
# 2014     88
# 2012     64
# 2013     63
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
Releaseyearwise_TV_Shows.plot(kind='bar', color='yellow')
plt.title('Releaseyearwise top 10 TV Shows')
plt.xlabel('Year')
plt.ylabel('Count')
plt.ylim(bottom=0)
plt.show()

# %%
Ratingwise_Movies=x['rating'][x['type']=='Movie'].value_counts().sort_values(ascending=False).head(10)
print(Ratingwise_Movies)
# Out:
# rating
# TV-MA    2062
# TV-14    1427
# R         797
# TV-PG     540
# PG-13     490
# PG        287
# TV-Y7     139
# TV-Y      131
# TV-G      126
# NR         75
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
Ratingwise_Movies.plot(kind='pie')
plt.title('Ratingwise top 10 Movies')
plt.legend()
plt.show()

# %%
Ratingwise_TV_Shows=x['rating'][x['type']=='TV Show'].value_counts().sort_values(ascending=False).head(10)
print(Ratingwise_TV_Shows)
# Out:
# rating
# TV-MA       1145
# TV-14        733
# TV-PG        323
# TV-Y7        195
# TV-Y         176
# TV-G          94
# NR             5
# R              2
# TV-Y7-FV       1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
Ratingwise_TV_Shows.plot(kind='pie')
plt.title('Ratingwise top 10 TV shows')
plt.legend()
plt.show()

# %%
durationtime_Movies=x['duration'][x['type']=='Movie'].value_counts().sort_values(ascending=False).head(10)
print(durationtime_Movies)
# Out:
# duration
# 90 min     152
# 94 min     146
# 93 min     146
# 97 min     146
# 91 min     144
# 95 min     137
# 96 min     130
# 92 min     129
# 102 min    122
# 98 min     120
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
Durationtime_Movies.plot(kind='bar',color='gray')
plt.title('Durationtime top 10 Movies')
plt.xlabel('Duration')
plt.ylabel('Count')
plt.show()

# %%
durationtime_TV_Shows=x['duration'][x['type']=='TV Show'].value_counts().sort_values(ascending=False).head(10)
print(durationtime_TV_Shows)
# Out:
# duration
# 1 Season      1793
# 2 Seasons      425
# 3 Seasons      199
# 4 Seasons       95
# 5 Seasons       65
# 6 Seasons       33
# 7 Seasons       23
# 8 Seasons       17
# 9 Seasons        9
# 10 Seasons       7
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
durationtime_TV_Shows.plot(kind='bar',color='blue')
plt.title('Durationtime top 10 TV Shows')
plt.xlabel('Duration')
plt.ylabel('Count')
plt.show()

# %%
listedwise_Movies=x['listed_in'][x['type']=='Movie'].value_counts().sort_values(ascending=False).head(10)
print(listedwise_Movies)
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Comedies, International Movies                      176
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
listedwise_Movies.plot(kind='barh',color='pink')
plt.title('Listedwise top 10 Movies')
plt.ylabel('List of Movies')
plt.xlabel('Count')
plt.show()

# %%
listedwise_TV_Shows=x['listed_in'][x['type']=='TV Show'].value_counts().sort_values(ascending=False).head(10)
print(listedwise_TV_Shows)
# Out:
# listed_in
# Kids' TV                                                  220
# International TV Shows, TV Dramas                         121
# Crime TV Shows, International TV Shows, TV Dramas         110
# Kids' TV, TV Comedies                                      99
# Reality TV                                                 95
# International TV Shows, Romantic TV Shows, TV Comedies     94
# International TV Shows, Romantic TV Shows, TV Dramas       90
# Anime Series, International TV Shows                       88
# Docuseries                                                 85
# TV Comedies                                                69
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
listedwise_TV_Shows.plot(kind='barh',color='black')
plt.title('Listedwise top 10 TV Shows')
plt.ylabel('List of TV shows')
plt.xlabel('Count')
plt.show()
